# %%
import csv
import pandas as pd

# %% [markdown]
# ### Try importing csv file

# %%
pd.read_csv(r'./data/data_engineering_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-76-93ecbbfd17dd> in <module>()
# ----> 1 pd.read_csv(r'./data/data_engineering_dataset.csv')
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 11388, saw 30

# %% [markdown]
# ### Getting a parser error which suggests there are extra columns in a problematic line... let's investigate.

# %%
with open('./data/data_engineering_dataset.csv') as fd:
    reader=csv.reader(fd)
    interestingrows=[row for idx, row in enumerate(reader) if idx in (11387,)]
    print(interestingrows)
# Out:
# [['5GZCZ33D16S845647', '2006', 'Silver', 'SUV', '4 Cylinder', 'VUE                      ', '95136', 'Accurate', 'SATURN', 'Truck', '465', 'SUV', '2.2L', 'GasolinVIN', 'CarYear', 'Color', 'VehBody', 'EngineType', 'Make', 'Miles', 'Odometer', 'Brand', 'VehType', 'LocationNum', 'CarType', 'EngineLiters', 'FuelType', 'Transmission', 'SaleLoc', 'PurchVal']]

# %% [markdown]
# ### It looks like this row had the columns values inserted into it... this is suspicious, let's investigate further.

# %%
with open('./data/data_engineering_dataset.csv') as fd:
    reader=csv.reader(fd)
    interestingrows=[row for idx, row in enumerate(reader) if idx in (11387*2,)]
    print(interestingrows)
# Out:
# [['5GZCZ33D16S845647', '2006', 'Silver', 'SUV', '4 Cylinder', 'VUE                      ', '95136', 'Accurate', 'SATURN', 'Truck', '465', 'SUV', '2.2L', 'Gasoline', 'Automatic', '465', '5500']]

# %% [markdown]
# ### This appears to be a duplicate row... My suspicion is that there are more duplicate rows, perhaps duplicated data was accidentally inserted into this dataset file.

# %%
#Read the file with explicit columns to remove the problem from the extra cols
df = pd.read_csv(r'./data/data_engineering_dataset.csv', names = ['VIN',	'CarYear',	'Color',	'VehBody',	'EngineType',	'Make',	'Miles',	'Odometer',	'Brand',	'VehType',	
                                                                  'LocationNum',	'CarType',	'EngineLiters',
                                                                  'FuelType',	'Transmission',	'SaleLoc',	'PurchVal'], skiprows = 1)

# %%
#Split these rows in their own df and compare them.
df1 = df.iloc[0:11387]
df2 = df.iloc[11387:11387*2]

#Returns just the rows from the new df that differ from the source df.
def get_different_rows(source_df, new_df):
    merged_df = source_df.merge(new_df, indicator=True, how='outer')
    changed_rows_df = merged_df[merged_df['_merge'] == 'right_only']
    return changed_rows_df.drop('_merge', axis=1)

#Find differences.
get_different_rows(df1,df2)
# Out:
#                      VIN  CarYear   Color VehBody  EngineType  \
# 11387  5GZCZ33D16S845647     2006  Silver     SUV  4 Cylinder
#
#                             Make    Miles  Odometer   Brand VehType  \
# 11387  VUE                        95136.0  Accurate  SATURN   Truck
#
#        LocationNum CarType EngineLiters  FuelType Transmission SaleLoc  \
# 11387          465     SUV         2.2L  Gasoline    Automatic     465
#
#       PurchVal
# 11387     5500

# %% [markdown]
# ### No differences found between these rows, I can comfortably assume that this is duplicated data and it should be removed from the dataset.

# %% [markdown]
# ### Let's try ignoring this row to see if there are any other problems with the file.

# %%
pd.read_csv(r'./data/data_engineering_dataset.csv', skiprows=[0,11387])
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-99-1e8d0c0c5f1f> in <module>()
# ----> 1 pd.read_csv(r'./data/data_engineering_dataset.csv', skiprows=[0,11387])
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 22782, saw 20

# %%
with open('./data/data_engineering_dataset.csv') as fd:
    reader=csv.reader(fd)
    interestingrows=[row for idx, row in enumerate(reader) if idx in (22781,)]
    print(interestingrows)
# Out:
# [['1G4HP52K834149596', '2003', 'White', '4 Door', '6 Cylinder', 'LESABRE CUSTOM           ', '117896', 'Accurate', 'BUICK', 'Passenger', '391', 'Full-size', '3.8L', 'Gasoline', 'Automatic', '391', '5500e', 'Automatic', '465', '5500']]

# %% [markdown]
# ### Looks like this could be another copy-paste error.. let's inspect these rows to find out more.

# %%
df.iloc[11387*2:]
# Out:
#                      VIN  CarYear   Color VehBody  EngineType  \
# 22774  2CNDL73FX66077410     2006    Gray     SUV  6 Cylinder
# 22775  1G1AD5F56A7169546     2010     Red  4 Door  4 Cylinder
# 22776  1G1AL58F787211970     2008   White  4 Door  4 Cylinder
# 22777  2FTRF17274CA55319     2004  Silver   Truck  6 Cylinder
# 22778  1FMCU03108KC39727     2008    Grey     SUV  6 Cylinder
# 22779  4A3AB26FX4E088213     2004   Black  4 Door  4 Cylinder
# 22780  1G4HP52K834149596     2003   White  4 Door  6 Cylinder
# 22781  2CNDL73FX66077410     2006    Gray     SUV  6 Cylinder
# 22782  1G1AD5F56A7169546     2010     Red  4 Door  4 Cylinder
# 22783  1G1AL58F787211970     2008   White  4 Door  4 Cylinder
# 22784  2FTRF17274CA55319     2004  Silver   Truck  6 Cylinder
# 22785  1FMCU03108KC39727     2008    Grey     SUV  6 Cylinder
# 22786  4A3AB26FX4E088213     2004   Black  4 Door  4 Cylinder
# 22787  1G4HP52K834149596     2003   White  4 Door  6 Cylinder
#
#                             Make         Miles    Odometer       Brand  \
# 22774                    EQUINOX  109057.00000    Accurate   CHEVROLET
# 22775  COBALT                      84970.00000    Accurate   CHEVROLET
# 22776  COBALT                      92982.00000    Accurate   CHEVROLET
# 22777  F150 HERITAGE               95201.00000    Accurate        FORD
# 22778  ESCAPE XLT                 115005.00000  Inaccurate        FORD
# 22779  GALANT DE                   80339.66667    Accurate  MITSUBISHI
# 22780  LESABRE CUSTOM             117896.00000    Accurate       BUICK
# 22781                    EQUINOX  109057.00000    Accurate   CHEVROLET
# 22782  COBALT                      84970.00000    Accurate   CHEVROLET
# 22783  COBALT                      92982.00000    Accurate   CHEVROLET
# 22784  F150 HERITAGE               95201.00000    Accurate        FORD
# 22785  ESCAPE XLT                 115005.00000  Inaccurate        FORD
# 22786  GALANT DE                   80339.66667    Accurate  MITSUBISHI
# 22787  LESABRE CUSTOM             117896.00000    Accurate       BUICK
#
#          VehType  LocationNum          CarType EngineLiters  FuelType  \
# 22774      Truck          466              SUV         3.4L  Gasoline
# 22775  Passenger          481          Compact         2.2L  Gasoline
# 22776  Passenger          223          Compact         2.2L  Gasoline
# 22777      Truck           81  Full-Size Truck         4.2L  Gasoline
# 22778      Truck          437              SUV         3.0L  Gasoline
# 22779  Passenger          442         Mid-size         2.4L  Gasoline
# 22780  Passenger          391        Full-size         3.8L  Gasoline
# 22781      Truck          466              SUV         3.4L  Gasoline
# 22782  Passenger          481          Compact         2.2L  Gasoline
# 22783  Passenger          223          Compact         2.2L  Gasoline
# 22784      Truck           81  Full-Size Truck         4.2L  Gasoline
# 22785      Truck          437              SUV         3.0L  Gasoline
# 22786  Passenger          442         Mid-size         2.4L  Gasoline
# 22787  Passenger          391        Full-size         3.8L  Gasoline
#
#       Transmission SaleLoc PurchVal
# 22774    Automatic     466     4480
# 22775      5-Speed     481     5000
# 22776    Automatic     223     3800
# 22777      5-Speed      81     4800
# 22778    Automatic     437     5740
# 22779    Automatic     442     4400
# 22780    Automatic     391    5500e
# 22781    Automatic     466     4480
# 22782      5-Speed     481     5000
# 22783    Automatic     223     3800
# 22784      5-Speed      81     4800
# 22785    Automatic     437     5740
# 22786    Automatic     442     4400
# 22787    Automatic     391     5500

# %% [markdown]
# ### More duplicated data... we can safely remove it from the dataset as well.

# %%
#Remove first set of duplicate data
cleaned_df = df.drop(df.index[0:11387])
#Reset index
cleaned_df.reset_index(inplace=True, drop=True)
#Remove second set of duplicated data
cleaned_df = cleaned_df.drop(df.index[11387:11394])
#Reset index
cleaned_df.reset_index(inplace=True, drop=True)
cleaned_df.head()
# Out:
#                  VIN  CarYear   Color VehBody  EngineType  \
# 0  1G1AL15F777226903     2007  Silver  2 Door  4 Cylinder
# 1  5NPEU46C66H126152     2006  Silver  4 Door  4 Cylinder
# 2  3MEHM08Z48R665374     2008   White  4 Door  4 Cylinder
# 3  1HGCP2F81AA000524     2010     Red  4 Door  4 Cylinder
# 4  2G2WC52C951325364     2005  Maroon  4 Door  8 Cylinder
#
#                         Make     Miles  Odometer      Brand    VehType  \
# 0  COBALT LT                  117029.0  Accurate  CHEVROLET  Passenger
# 1  SONATA GLS/LX              108890.0  Accurate    HYUNDAI  Passenger
# 2  MILAN                      138000.0  Accurate    MERCURY  Passenger
# 3  ACCORD                      89643.0  Accurate      HONDA  Passenger
# 4  GRAND PRIX                 127806.0  Accurate    PONTIAC  Passenger
#
#    LocationNum    CarType EngineLiters  FuelType Transmission SaleLoc PurchVal
# 0           86    Compact         2.2L  Gasoline    Automatic      86     4900
# 1          189  Full-size         2.4L  Gasoline    Automatic     189     5700
# 2          360  Full-size         2.3L  Gasoline    Automatic     360     2890
# 3          302   Mid-size         2.4L  Gasoline    Automatic     302     9000
# 4          295  Full-size         5.3L  Gasoline    Automatic     295     4000

# %% [markdown]
# ### Standard data cleaning

# %%
cleaned_df['Color'] = cleaned_df['Color'].str.upper()
cleaned_df['VIN'] = cleaned_df['VIN'].str.upper()
cleaned_df['Make'] = cleaned_df['Make'].str.rstrip()
cleaned_df['EngineLiters'] = cleaned_df['EngineLiters'].str.strip('L')

# %%
cleaned_df.to_csv('./data/data_engineering_dataset_cleaned.csv')
